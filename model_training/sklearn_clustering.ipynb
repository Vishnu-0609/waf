# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import joblib

# %%
df = pd.read_csv("sample.csv")

# %%
features = ['single_q','double_q','dashes','braces','spaces','badwords']
X = df[features]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
joblib.dump(kmeans, "kmeans_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
#testing

# %%
kmeans = joblib.load("kmeans_model.pkl")
scaler = joblib.load("scaler.pkl")

# %%
test_df = pd.read_csv("test.csv")

# %%
features = ['single_q','double_q','dashes','braces','spaces','badwords']
X_test = test_df[features]

# Scale test data
X_test_scaled = scaler.transform(X_test)

# Predict
test_df["Cluster"] = kmeans.predict(X_test_scaled)
print(test_df)


# pred = kmeans.predict(scaled_features)[0]
# label = cluster_map[pred]

# print(label)
# Out:
#      method                                               path  \
# 0      POST                                /products/view?id=1
# 1       GET  /languages/english?q=%3Cimg+src%3Dx+onerror%3D...
# 2      POST                                     /locations/usa
# 3      POST                /tickets?q=1%3B+DROP+TABLE+users%3B
# 4      POST                                            /crypto
# ...     ...                                                ...
# 9995    GET                                  /search?q=laptops
# 9996   POST                                     /travel/hotels
# 9997    GET                                  /api/v3/dashboard
# 9998    GET                                 /auth/verify-email
# 9999    GET                    /page/2?q=%22+OR+%221%22%3D%221
#
#                                body  single_q  double_q  dashes  braces  \
# 0              uname=test&pass=test         0         0       0       0
# 1                               NaN         0         0       0       1
# 2              comment=Nice+product         0         0       0       0
# 3     data=1%3B+DROP+TABLE+users%3B         0         0       0       0
# 4        searchFor=book&goButton=go         0         0       0       0
# ...                             ...       ...       ...     ...     ...
# 9995                            NaN         0         0       0       0
# 9996                            NaN         0         0       0       0
# 9997                            NaN         0         0       0       0
# 9998                            NaN         0         0       0       0
# 9999                            NaN         0         4       0       0
#
#       spaces  badwords  Cluster
# 0          0         0        0
# 1          2         1        0
# 2          1         0        0
# 3          6         4        0
# 4          0         0        0
# ...      ...       ...      ...
# 9995       0         0        0
# 9996       0         0        0
# 9997       0         0        0
# 9998       0         0        0
# 9999       2         0        1
#
# [10000 rows x 10 columns]

# %%
test_df.to_csv("test_result.csv", index=False)
print(test_df.tail())
# Out:
#      method                             path body  single_q  double_q  dashes  \
# 9995    GET                /search?q=laptops  NaN         0         0       0
# 9996   POST                   /travel/hotels  NaN         0         0       0
# 9997    GET                /api/v3/dashboard  NaN         0         0       0
# 9998    GET               /auth/verify-email  NaN         0         0       0
# 9999    GET  /page/2?q=%22+OR+%221%22%3D%221  NaN         0         4       0
#
#       braces  spaces  badwords  Cluster
# 9995       0       0         0        0
# 9996       0       0         0        0
# 9997       0       0         0        0
# 9998       0       0         0        0
# 9999       0       2         0        1
